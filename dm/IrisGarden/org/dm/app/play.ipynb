# %%
3 + 4
# Out:
# 7

# %%
8 * 4
# Out:
# 32

# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.DataFrame(np.random.rand(1000,3),columns=['a','b','c'])

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.253610</td>
#       <td>0.007155</td>
#       <td>0.332142</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.191012</td>
#       <td>0.698745</td>
#       <td>0.474625</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.514738</td>
#       <td>0.739730</td>
#       <td>0.333767</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.181886</td>
#       <td>0.800047</td>
#       <td>0.661188</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.894433</td>
# ...

# %%
# %matplotlib inline

# %%
df.plot.scatter(x='a',y='b',c='c',s=df['c']*100,cmap='spring')
